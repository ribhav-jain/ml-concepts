# %% [markdown]
# # Streamlit Overview
#
# Streamlit is an open-source Python library that makes it easy to create interactive and user-friendly web applications for data visualization, machine learning, and other data-driven applications.
#
# ---
#
# ## **Key Features of Streamlit**
#
# 1. **Ease of Use**:
#
#    - Write pure Python code; no need for HTML, CSS, or JavaScript.
#    - Leverages Python libraries like Matplotlib, Plotly, Altair, and more.
#
# 2. **Real-Time Interactivity**:
#
#    - Widgets like sliders, buttons, text inputs, and dropdowns allow for dynamic interaction with your data or models.
#
# 3. **Automatic UI Updates**:
#
#    - Streamlit automatically detects changes in code and updates the interface.
#
# 4. **Python First**:
#
#    - Integrates seamlessly with Python libraries, allowing you to use your existing tools and knowledge.
#
# 5. **Data Visualization**:
#
#    - Support for various visualization libraries and custom chart generation.
#
# 6. **Scalability**:
#    - Deploy easily using platforms like Streamlit Community Cloud, AWS, GCP, or Heroku.
#
# ---
#
# ## **Installation**
#
# To install Streamlit:
#
# ```bash
# pip install streamlit
# ```

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in d:\workspace\python-concepts-master\.venv\lib\site-packages (1.40.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: altair<6,>=4.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (5.29.1)
# Requirement already satisfied: pyarrow>=7.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.16.0)
# Requirement already satisfied: colorama in d:\workspace\python-concepts-master\.venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in d:\workspace\python-concepts-master\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)

# %%
import streamlit as st

# Title and text
st.title("Hello, Streamlit!")
st.write("This is a simple Streamlit app.")

# Input and output
name = st.text_input("Enter your name:")
st.write(f"Hello, {name}!")

# Slider
age = st.slider("Select your age:", 0, 100)
st.write(f"You are {age} years old.")

# %% [markdown]
# ### Run
#
# streamlit run app.py

# %% [markdown]
# ## Common Widgets
#
# - **Text Input**: `st.text_input()`
# - **Button**: `st.button()`
# - **Checkbox**: `st.checkbox()`
# - **Slider**: `st.slider()`
# - **Selectbox**: `st.selectbox()`
# - **File Uploader**: `st.file_uploader()`
#
# ---
#
# ## Deployment
#
# ### Streamlit Cloud:
#
# 1. Push your app to a GitHub repository.
# 2. Deploy it on Streamlit Cloud for free.
#
# ### Docker:
#
# - Build a Docker image and run it in any containerized environment.
#
# ### Web Servers:
#
# - Deploy with Gunicorn, AWS EC2, or any other hosting service.
#
# ---
#
# ## Use Cases
#
# ### Data Exploration and Visualization:
#
# - Interactive dashboards for business intelligence.
#
# ### Machine Learning:
#
# - Share models with sliders and input fields for experimentation.
#
# ### Prototyping:
#
# - Rapid development of proof-of-concept applications.
